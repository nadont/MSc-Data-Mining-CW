# %%
#%pip install pyLDAvis --user
#%pip install gensim

# %%
import numpy as np 
import pandas as pd 

import nltk
import string

from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

import gensim
from gensim.utils import simple_preprocess

import pyLDAvis.gensim_models
import pyLDAvis

from nltk.stem import WordNetLemmatizer 
from nltk.corpus import wordnet

import gensim.corpora as corpora  
from pprint import pprint

# %%
reviews = pd.read_csv('yelp_labelled.csv')
reviews = reviews.astype({'Text':'string'})
text = reviews['Text']
text1 = []
for review in text:
    #print(sentence)
    #remove punctuation
    review = review.translate(str.maketrans('', '', string.punctuation))  
    # remove digits/numbers
    review = review.translate(str.maketrans('', '', string.digits))
    #change to lowercase
    review = review.lower()
    #print(sentence)
    text1.append(review)
text1 = pd.Series(text1)
stop_words = set(stopwords.words('english'))

text1 = text1.apply(lambda x: ' '.join(term for term in x.split() if term not in stop_words))
def get_wordnet_pos(word):

    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)


lemmatizer = WordNetLemmatizer()
text3 = text1.apply(lambda x:' '.join(lemmatizer.lemmatize(w, get_wordnet_pos(w)) for w in x.split()))
label = reviews['Sentiment']
reviews1 = list(zip(text3, label))

reviewsP = pd.DataFrame (reviews1, columns = ['Review', 'Sentiment'])
reviewsP.head()
# Out:
#                                               Review  Sentiment
# 0                                     wow love place          1
# 1                                         crust good          0
# 2                                tasty texture nasty          0
# 3  stop late may bank holiday rick steve recommen...          1
# 4                         selection menu great price          1

# %%
data = reviewsP.Review.values.tolist()

# %%
data
# Out:
# ['wow love place',
#  'crust good',
#  'tasty texture nasty',
#  'stop late may bank holiday rick steve recommendation love',
#  'selection menu great price',
#  'get angry want damn pho',
#  'honeslty didnt taste fresh',
#  'potato like rubber could tell make ahead time kept warmer',
#  'fry great',
#  'great touch',
#  'service prompt',
#  'would go back',
#  'cashier care ever say still end wayyy overprice',
#  'try cape cod ravoli chickenwith cranberrymmmm',
#  'disgust pretty sure human hair',
#  'shock sign indicate cash',
#  'highly recommend',
#  'waitress little slow service',
#  'place worth time let alone vega',
#  'like',
#  'burrittos blah',
#  'food amaze',
#  'service also cute',
#  'could care less interior beautiful',
#  'perform',
#  'thats rightthe red velvet cakeohhh stuff good',
#  'never brought salad ask',
#  'hole wall great mexican street taco friendly staff',
#  'take hour get food table restaurant food luke warm sever run around like totally overwhelmed',
#  'bad salmon sashimi',
#  'also combo like burger fry beer decent deal',
#  'like final blow',
#  'found place accident could happier',
#  'seem like good quick place grab bite familiar pub food favor look elsewhere',
#  'overall like place lot',
#  'redeem quality restaurant inexpensive',
#  'ample portion good price',
#  'poor service waiter make feel like stupid every time come table',
#  'first visit hiro delight',
#  'service suck',
#  'shrimp tender moist',
#  'deal good enough would drag establishment',
#  'hard judge whether side good gross melt styrofoam didnt want eat fear get sick',
#  'positive note server attentive provide great service',
#  'frozen puck disgust bad people behind register',
#  'thing like prime rib dessert section',
#  'bad food damn generic',
#  'burger good beef cooked right',
#  'want sandwich go firehouse',
#  'side greek salad greek dress tasty pita hummus refresh',
#  'order duck rare pink tender inside nice char outside',
#  'come run u realize husband left sunglass table',
#  'chow mein good',
#  'horrible attitude towards customer talk one customer dont enjoy food',
#  'portion huge',
#  'love itfriendly server great food wonderful imaginative menu',
#  'heart attack grill downtown vega absolutely flatlined excuse restaurant',
#  'much seafood like string pasta bottom',
#  'salad right amount sauce power scallop perfectly cooked',
#  'ripped banana ripped petrify tasteless',
#  'least think refill water struggle wave minute',
#  'place receives star appetizer',
#  'cocktail handmade delicious',
#  'wed definitely go back',
#  'glad found place',
#  'great food service huge portion give military discount',
#  'always great time do gringo',
#  'updatewent back second time still amaze',
#  'get food apparently never heard salt batter fish chewy',
#  'great way finish great',
#  'deal include tasting drink jeff go beyond expect',
#  'really really good rice time',
#  'service meh',
#  'take min get milkshake nothing chocolate milk',
#  'guess know place would suck inside excalibur didnt use common sense',
#  'scallop dish quite appal value well',
#  'time bad customer service',
#  'sweet potato fry good season well',
#  'today second time ive lunch buffet pretty good',
#  'much good food vega feel cheat waste eat opportunity go rice company',
#  'come like experience underwhelming relationship party cant wait person ask break',
#  'walk place smell like old grease trap others eat',
#  'turkey roast beef bland',
#  'place',
#  'pan cake everyone rave taste like sugary disaster tailor palate six year old',
#  'love pho spring roll oh yummy try',
#  'poor batter meat ratio make chicken tender unsatisfying',
#  'say food amaze',
#  'omelet die',
#  'everything fresh delicious',
#  'summary largely disappoint din experience',
#  'like really sexy party mouth youre outrageously flirt hottest person party',
#  'never hard rock casino never ever step forward',
#  'best breakfast buffet',
#  'say bye bye tip lady',
#  'well never go',
#  'back',
#  'food arrive quickly',
#  'good',
#  'side cafe serf really good food',
#  'server fantastic found wife love roast garlic bone marrow add extra meal another marrow go',
#  'good thing waiter helpful kept bloddy mary come',
#  'best buffet town price cannot beat',
#  'love mussel cooked wine reduction duck tender potato dish delicious',
#  'one well buffet',
#  'go tigerlilly fantastic afternoon',
#  'food delicious bartender attentive personable get great deal',
#  'ambience wonderful music play',
#  'go back next trip',
#  'sooooo good',
#  'real sushi lover let honest yama good',
#  'least min pass u order food arrive wasnt busy',
#  'really fantastic thai restaurant definitely worth visit',
#  'nice spicy tender',
#  'good price',
#  'check',
#  'pretty gross',
#  'ive well atmosphere',
#  'kind hard mess steak',
#  'although much like look sound place actual experience bit disappoint',
#  'dont know place manage serve blandest food ever eat prepare indian cuisine',
#  'bad service boot least worry',
#  'service fine waitress friendly',
#  'guy steak steak love son steak best bad place say best steak he ever eat',
#  'thought youd venture away get good sushi place really hit spot night',
#  'host staff lack well word bitch',
#  'bland like place number reason dont want waste time bad review ill leave',
#  'phenomenal food service ambiance',
#  'wouldnt return',
#  'definitely worth venture strip pork belly return next time im vega',
#  'place way overprice mediocre food',
#  'penne vodka excellent',
#  'good selection food include massive meatloaf sandwich crispy chicken wrap delish tuna melt tasty burger',
#  'management rude',
#  'delicious nyc bagel good selection cream cheese real lox caper even',
#  'great subway fact good come every subway meet expectation',
#  'seriously solid breakfast',
#  'one best bar food vega',
#  'extremely rude really many restaurant would love dine weekend vega',
#  'drink never empty make really great menu suggestion',
#  'dont',
#  'waiter wasnt helpful friendly rarely checked u',
#  'husband ate lunch disappointed food service',
#  'red curry much bamboo shoot wasnt tasty',
#  'nice blanket moz top feel like do cover subpar food',
#  'bathroom clean place well decorate',
#  'menu always change food quality go service extremely slow',
#  'service little slow consider serve people server food come slow pace',
#  'give thumb',
#  'watch waiter pay lot attention table ignore u',
#  'fiancé come middle day greet seat right away',
#  'great restaurant mandalay bay',
#  'wait forty five minute vain',
#  'crostini come salad stale',
#  'highlight great quality nigiri',
#  'staff friendly joint always clean',
#  'different cut piece day still wonderful tender well well flavor',
#  'order voodoo pasta first time id really excellent pasta since go gluten free several year ago',
#  'place good',
#  'unfortunately must hit bakery leftover day everything order stale',
#  'come back today since relocate still impressed',
#  'seat immediately',
#  'menu diverse reasonably price',
#  'avoid cost',
#  'restaurant always full never wait',
#  'delicious',
#  'place handsdown one best place eat phoenix metro area',
#  'dont go look good food',
#  'ive never treat bad',
#  'bacon hella salty',
#  'also order spinach avocado salad ingredient sad dress literally zero taste',
#  'really vega fine din use right menu hand lady price list',
#  'waitress friendly',
#  'lordy khao soi dish miss curry lover',
#  'everything menu terrific also thrill make amaze accommodation vegetarian daughter',
#  'perhaps caught night judging review im inspire go back',
#  'service leaf lot desire',
#  'atmosphere modern hip maintain touch coziness',
#  'weekly haunt definitely place come back every',
#  'literally sat minute one ask take order',
#  'burger absolutely flavor meat totally bland burger overcook charcoal flavor',
#  'also decide send back waitress look like verge heart attack',
#  'dress treat rudely',
#  'probably dirt',
#  'love place hit spot want something healthy lack quantity flavor',
#  'order lemon raspberry ice cocktail also incredible',
#  'food suck expect suck could imagine',
#  'interest decor',
#  'really like crepe station',
#  'also serve hot bread butter home make potato chip bacon bit topvery original good',
#  'watch prepare delicious food',
#  'egg roll fantastic',
#  'order arrive one gyro miss',
#  'salad wing ice cream dessert left feel quite satisfied',
#  'im really sure joeys vote best hot dog valley reader phoenix magazine',
#  'best place go tasty bowl pho',
#  'live music friday totally blow',
#  'ive never insult felt disrespect',
#  'friendly staff',
#  'worth drive',
#  'heard good thing place exceed every hope could dream',
#  'food great serivce',
#  'warm beer didnt help',
#  'great brunch spot',
#  'service friendly invite',
#  'good lunch spot',
#  'ive live since first last time ive step foot place',
#  'bad experience ever',
#  'must night place',
#  'side delish mixed mushroom yukon gold puree white corn beateous',
#  'bug never show would give sure side wall bug climb kitchen',
#  'minute wait salad realize wasnt come time soon',
#  'friend love salmon tartar',
#  'wont go back',
#  'extremely tasty',
#  'waitress good though',
#  'soggy good',
#  'jamaican mojitos delicious',
#  'small worth price',
#  'food rich order accordingly',
#  'shower area outside rinse take full shower unless dont mind nude everyone see',
#  'service bit lack',
#  'lobster bisque bussell sprout risotto filet need salt pepperand course none table',
#  'hopefully bodes go business someone cook come',
#  'either cold enough flavor bad',
#  'love bacon wrap date',
#  'unbelievable bargain',
#  'folk otto always make u feel welcome special',
#  'main also uninspired',
#  'place first pho amaze',
#  'wonderful experience make place muststop whenever town',
#  'food isnt bad enough enjoy deal world worstannoying drunk people',
#  'fun chef',
#  'order double cheeseburger get single patty fall apart picture uploaded yeah still suck',
#  'great place couple drink watch sport event wall cover tv',
#  'possible give zero star theyd',
#  'description say yum yum sauce another say eel sauce yet another say spicy mayowell none roll sauce',
#  'id say would hardest decision honestly m dish taste suppose taste amaze',
#  'roll eye may stayed sure go back try',
#  'everyone attentive provide excellent customer service',
#  'horrible dont waste time money',
#  'dish quite flavourful',
#  'time side restaurant almost empty excuse',
#  'wasnt busy either also building freeze cold',
#  'like reviewer say couldnt pay eat place',
#  'drink take close minute come one point',
#  'seriously flavorful delight folk',
#  'much well ayce sushi place go vega',
#  'light dark enough set mood',
#  'base subpar service receive effort show gratitude business wont go back',
#  'owner really great people',
#  'nothing privileged workingeating',
#  'greek dress creamy flavorful',
#  'overall dont think would take parent place make similar complaint silently felt',
#  'pizza good peanut sauce tasty',
#  'table service pretty fast',
#  'fantastic service',
#  'well wouldve give godfather zero star possible',
#  'know make',
#  'tough short flavor',
#  'hope place stick around',
#  'bar vega ever recall charge tap water',
#  'restaurant atmosphere exquisite',
#  'good service clean inexpensive boot',
#  'seafood fresh generous portion',
#  'plus buck',
#  'service par either',
#  'thus far visit twice food absolutely delicious time',
#  'good year ago',
#  'self proclaim coffee cafe wildly disappointed',
#  'veggitarian platter world',
#  'cant go wrong food',
#  'cant beat',
#  'stop place madison ironman friendly kind staff',
#  'chef friendly good job',
#  'ive well dedicate boba tea spot even jenni pho',
#  'like patio service outstanding',
#  'goat taco didnt skimp meat wow flavor',
#  'think',
#  'mac salad pretty bland get',
#  'go bachi burger friend recommendation disappointed',
#  'service stink',
#  'wait wait',
#  'place quality sushi quality restaurant',
#  'would definitely recommend wing well pizza',
#  'great pizza salad',
#  'thing go wrong burn saganaki',
#  'wait hour breakfast could do time well home',
#  'place amaze',
#  'hate disagree fellow yelpers husband disappointed place',
#  'wait hour never get either pizza many around u come later',
#  'dont know slow',
#  'staff great food delish incredible beer selection',
#  'live neighborhood disappointed wont back convenient location',
#  'didnt know pull pork could soooo delicious',
#  'get incredibly fresh fish prepared care',
#  'go give star rating please know third time eat bachi burger write review',
#  'love fact everything menu worth',
#  'never din place',
#  'food excellent service good',
#  'good beer drink selection good food selection',
#  'please stay away shrimp stir fry noodle',
#  'potato chip order sad could probably count many chip box probably around',
#  'food really boring',
#  'good servicecheck',
#  'greedy corporation never see another dime',
#  'never ever go back',
#  'much id like go back cant get pass atrocious service never return',
#  'summer dine charm outdoor patio delightful',
#  'expect good',
#  'fantastic food',
#  'order toast english muffin come untoasted',
#  'food good',
#  'never go back',
#  'great food price high quality house make',
#  'bus boy hand rude',
#  'point friend basically figure place joke didnt mind make publicly loudly know',
#  'back good bbq lighter fare reasonable pricing tell public back old way',
#  'consider two u left full happy cant go wrong',
#  'bread make inhouse',
#  'downside service',
#  'also fry without doubt bad fry ive ever',
#  'service exceptional food good review',
#  'couple month later return amaze meal',
#  'favorite place town shawarrrrrrma',
#  'black eyed pea sweet potato unreal',
#  'wont disappointed',
#  'could serve vinaigrette may make well overall dish still good',
#  'go far many place ive never see restaurant serf egg breakfast especially',
#  'mom get home immediately get sick bite salad',
#  'server pleasant deal dont always honor pizza hut coupon',
#  'truly unbelievably good glad go back',
#  'fantastic service pleased atmosphere',
#  'everything gross',
#  'love place',
#  'great service food',
#  'first bathroom location dirty seat cover replenish plain yucky',
#  'burger get gold standard burger kind disappointed',
#  'omg food delicioso',
#  'nothing authentic place',
#  'spaghetti nothing special whatsoever',
#  'dish salmon best great',
#  'vegetable fresh sauce feel like authentic thai',
#  'worth drive tucson',
#  'selection probably bad ive see vegasthere none',
#  'pretty good beer selection',
#  'place like chipotle well',
#  'classywarm atmosphere fun fresh appetizer succulent steak baseball steak',
#  'star brick oven bread app',
#  'eat multiple time time food delicious',
#  'sat another ten minute finally give left',
#  'terrible',
#  'everyone treat equally special',
#  'shouldnt take min pancake egg',
#  'delicious',
#  'good side staff genuinely pleasant enthusiastic real treat',
#  'sadly gordon ramseys steak place shall sharply avoid next trip vega',
#  'always even wonderful food delicious',
#  'best fish ive ever life',
#  'bathroom next door nice',
#  'buffet small food offer bland',
#  'outstanding little restaurant best food ever taste',
#  'pretty cool would say',
#  'definitely turn doubt ill back unless someone else buying',
#  'server great job handle large rowdy table',
#  'find waste food despicable wasnt food',
#  'wife lobster bisque soup lukewarm',
#  'would come back sushi crave vega',
#  'staff great ambiance great',
#  'deserves star',
#  'left stomach ache felt sick rest day',
#  'drop ball',
#  'din space tiny elegantly decorate comfortable',
#  'customize order way youd like usual eggplant green bean stir fry love',
#  'bean rice mediocre best',
#  'best taco town far',
#  'take back money get outta',
#  'interest part town place amaze',
#  'rude inconsiderate management',
#  'staff friendly wait time serve horrible one even say hi first minute',
#  'wont back',
#  'great dinner',
#  'service outshine definitely recommend halibut',
#  'food terrible',
#  'never ever go back told many people happen',
#  'dont recommend unless car break front starve',
#  'come back every time im vega',
#  'place deserves one star food',
#  'disgrace',
#  'def come back bowl next time',
#  'want healthy authentic ethic food try place',
#  'continue come lady night andddd date night highly recommend place anyone area',
#  'several time past experience always great',
#  'walk away stuffed happy first vega buffet experience',
#  'service excellent price pretty reasonable consider vega locate inside crystal shopping mall aria',
#  'summarize food incredible nay transcendant nothing brings joy quite like memory pneumatic condiment dispenser',
#  'im probably one people ever go ians like',
#  'kid pizza always hit lot great side dish option kiddos',
#  'service perfect family atmosphere nice see',
#  'cooked perfection service impeccable',
#  'one simply disappointment',
#  'overall disappointed quality food bouchon',
#  'dont accountant know im get screw',
#  'great place eat reminds little mom pop shop san francisco bay area',
#  'today first taste buldogis gourmet hot dog tell ever thought possible',
#  'left frustrate',
#  'ill definitely soon',
#  'food really good get full petty fast',
#  'service fantastic',
#  'total waste time',
#  'dont know kind best iced tea',
#  'come hungry leave happy stuffed',
#  'service give star',
#  'assure wont disappointed',
#  'take little bad service food suck',
#  'give try eat crust teeth still sore',
#  'completely gross',
#  'really enjoy eat',
#  'first time go think quickly become regular',
#  'server nice even though look little overwhelmed need stayed professional friendly end',
#  'dinner companion told meeverything fresh nice texture taste',
#  'ground right next table large smear beensteppedinandtrackedeverywhere pile green bird poop',
#  'furthermore cant even find hour operation website',
#  'weve try like place time think do',
#  'mistake',
#  'complaint',
#  'seriously good pizza im expertconnisseur topic',
#  'waiter jerk',
#  'strike want rush',
#  'nice restaurant owner ive ever come across',
#  'never come',
#  'love biscuit',
#  'service quick friendly',
#  'order appetizer take minute pizza another minute',
#  'absolutley fantastic',
#  'huge awkward lb piece cow th gristle fat',
#  'definitely come back',
#  'like steiner dark feel like bar',
#  'wow spicy delicious',
#  'youre familiar check',
#  'ill take business dinner dollar elsewhere',
#  'id love go back',
#  'anyway f restaurant wonderful breakfastlunch',
#  'nothing special',
#  'day week different deal delicious',
#  'mention combination pear almond bacon big winner',
#  'back',
#  'sauce tasteless',
#  'food delicious spicy enough sure ask spicier prefer way',
#  'ribeye steak cooked perfectly great mesquite flavor',
#  'dont think well go back anytime soon',
#  'food gooodd',
#  'far sushi connoisseur definitely tell difference good food bad food certainly bad food',
#  'insult',
#  'last time lunch bad',
#  'chicken wing contain driest chicken meat ever eat',
#  'food good enjoy every mouthful enjoyable relaxed venue couple small family group etc',
#  'nargile think great',
#  'best tater tot southwest',
#  'love place',
#  'definitely worth paid',
#  'vanilla ice cream creamy smooth profiterole chou pastry fresh enough',
#  'im az time new spot',
#  'manager bad',
#  'inside really quite nice clean',
#  'food outstanding price reasonable',
#  'dont think ill run back carlys anytime soon food',
#  'due fact take minute acknowledge another minute get foodand kept forget thing',
#  'love margarita',
#  'first vega buffet disappoint',
#  'good though',
#  'one note ventilation could use upgrade',
#  'great pork sandwich',
#  'dont waste time',
#  'total letdown would much rather go camelback flower shop cartel coffee',
#  'third cheese friend burger cold',
#  'enjoy pizza brunch',
#  'steak well trim also perfectly cooked',
#  'group claimed would handle u beautifully',
#  'love',
#  'ask bill leave without eat didnt bring either',
#  'place jewel la vega exactly ive hop find nearly ten year living',
#  'seafood limited boil shrimp crab leg crab leg definitely taste fresh',
#  'selection food best',
#  'delicious absolutely back',
#  'isnt small family restaurant fine din establishment',
#  'toro tartare cavier extraordinary like thinly slice wagyu white truffle',
#  'dont think back long time',
#  'attach gas station rarely good sign',
#  'awesome',
#  'back many time soon',
#  'menu much good stuff could decide',
#  'bad humiliate worker right front mebunch horrible name calling',
#  'conclusion fill meal',
#  'daily special always hit group',
#  'tragedy struck',
#  'pancake also really good pretty large',
#  'first crawfish experience delicious',
#  'monster chicken fry steak egg time favorite',
#  'waitress sweet funny',
#  'also taste mom multigrain pumpkin pancake pecan butter amaze fluffy delicious',
#  'id rather eat airline food seriously',
#  'cant say enough good thing place',
#  'ambiance incredible',
#  'waitress manager friendly',
#  'would recommend place',
#  'overall wasnt impressed noca',
#  'gyro basically lettuce',
#  'terrible service',
#  'thoroughly disappointed',
#  'dont much pasta love homemade hand make pasta thin pizza',
#  'give try happy',
#  'far best cheesecurds ever',
#  'reasonably price also',
#  'everything perfect night',
#  'food good typical bar food',
#  'drive get',
#  'first glance lovely bakery cafe nice ambiance clean friendly staff',
#  'anyway think go back',
#  'point finger item menu order wont disappointed',
#  'oh thing beauty restaurant',
#  'havent go go',
#  'greasy unhealthy meal',
#  'first time might last',
#  'burger amaze',
#  'similarly delivery man say word apology food minute late',
#  'way expensive',
#  'sure order dessert even need pack togo tiramisu cannoli die',
#  'first time cant wait next',
#  'bartender also nice',
#  'everything good tasty',
#  'place two thumb upway',
#  'best place vega breakfast check sat sun',
#  'love authentic mexican food want whole bunch interest yet delicious meat choose need try place',
#  'terrible management',
#  'excellent new restaurant experienced frenchman',
#  'zero star would give zero star',
#  'great steak great side great wine amaze dessert',
#  'bad martini ever',
#  'steak shrimp opinion best entree gc',
#  'opportunity today sample amaze pizza',
#  'wait thirty minute seat although vacant table folk wait',
#  'yellowtail carpaccio melt mouth fresh',
#  'wont try go back even empty',
#  'im go eat potato found stranger hair',
#  'spicy enough perfect actually',
#  'last night second time din happy decide go back',
#  'even hello right',
#  'dessert bit strange',
#  'boyfriend come first time recent trip vega could pleased quality food service',
#  'really recommend place go wrong donut place',
#  'nice ambiance',
#  'would recommend save room',
#  'guess maybe go night disgraceful',
#  'however recent experience particular location good',
#  'know like restaurant something',
#  'avoid establishment',
#  'think restaurant suffers try hard enough',
#  'tapa dish delicious',
#  'heart place',
#  'salad bland vinegrette baby green heart palm',
#  'two felt disgust',
#  'good time',
#  'believe place great stop huge belly hanker sushi',
#  'generous portion great taste',
#  'never go back place never ever recommend place anyone',
#  'server go back forth several time even much help',
#  'food delicious',
#  'hour seriously',
#  'consider theft',
#  'eew location need complete overhaul',
#  'recently witness poor quality management towards guest well',
#  'wait wait wait',
#  'also come back check u regularly excellent service',
#  'server super nice checked u many time',
#  'pizza taste old super chewy good way',
#  'swung give try deeply disappointed',
#  'service good company well',
#  'staff also friendly efficient',
#  'service im fan quick youre serve nice folk',
#  'boy sucker dry',
#  'rat',
#  'look authentic thai food go else',
#  'steak recommend',
#  'pull car wait another minute acknowledge',
#  'great food great service clean friendly set',
#  'assure ill back',
#  'hate thing much cheap quality black olive',
#  'breakfast perpared great beautiful presentation giant slice toast lightly dust powder sugar',
#  'kid play area nasty',
#  'great place fo take eat',
#  'waitress friendly happy accomodate veganveggie option',
#  'omg felt like never eat thai food dish',
#  'extremely crumby pretty tasteless',
#  'pale color instead nice char flavor',
#  'crouton also taste homemade extra plus',
#  'get home see driest damn wing ever',
#  'itll regular stop trip phoenix',
#  'really enjoy crema café expand even told friend best breakfast',
#  'good money',
#  'miss wish one philadelphia',
#  'get sit fairly fast end wait minute place order another minute food arrive',
#  'also best cheese crisp town',
#  'good value great food great service',
#  'couldnt ask satisfy meal',
#  'food good',
#  'awesome',
#  'want leave',
#  'make drive way north scottsdale one bit disappointed',
#  'eat',
#  'owner really really need quit soooooo cheap let wrap freak sandwich two paper one',
#  'checked place couple year ago impressed',
#  'chicken get definitely reheat ok wedge cold soggy',
#  'sorry get food anytime soon',
#  'absolute must visit',
#  'cow tongue cheek taco amaze',
#  'friend like bloody mary',
#  'despite hard rate business actually rare give star',
#  'really want make experience good one',
#  'return',
#  'chicken pho taste bland',
#  'disappoint',
#  'grill chicken tender yellow saffron season',
#  'drive thru mean want wait around half hour food somehow end go make u wait wait',
#  'pretty awesome place',
#  'ambience perfect',
#  'best luck rude noncustomer service focus new management',
#  'grandmother make roast chicken well one',
#  'ask multiple time wine list time ignore go hostess get one',
#  'staff always super friendly helpful especially cool bring two small boy baby',
#  'four star food guy blue shirt great vibe still let u eat',
#  'roast beef sandwich taste really good',
#  'even drastically sick',
#  'highquality chicken chicken caesar salad',
#  'order burger rare come well do',
#  'promptly greet seat',
#  'try go lunch madhouse',
#  'proven dead wrong sushi bar quality great service fast food impeccable',
#  'wait hour seat great mood',
#  'good joint',
#  'macarons insanely good',
#  'im eat',
#  'waiter attentive friendly informative',
#  'maybe werent cold would somewhat edible',
#  'place lot promise fails deliver',
#  'bad experience',
#  'mistake',
#  'food average best',
#  'great food',
#  'wont go back anytime soon',
#  'disappointed order big bay plater',
#  'great place relax awesome burger beer',
#  'perfect sitdown family meal get together friend',
#  'much flavor poorly construct',
#  'patio seat comfortable',
#  'fry rice dry well',
#  'hand favorite italian restaurant',
#  'scream legit booksomethats also pretty rare vega',
#  'fun experience',
#  'atmosphere great lovely duo violinist play song request',
#  'personally love hummus pita baklava falafel baba ganoush amaze eggplant',
#  'convenient since stay mgm',
#  'owner super friendly staff courteous',
#  'great',
#  'eclectic selection',
#  'sweet potato tot good onion ring perfection close',
#  'staff attentive',
#  'chef generous time even come around twice take picture',
#  'owner use work nobu place really similar half price',
#  'google mediocre imagine smashburger pop',
#  'dont go',
#  'promise wont disappoint',
#  'sushi lover avoid place mean',
#  'great double cheeseburger',
#  'awesome service food',
#  'fantastic neighborhood gem',
#  'cant wait go back',
#  'plantain bad ive ever taste',
#  'great place highly recommend',
#  'service slow attentive',
#  'give star im give star',
#  'staff spends time talk',
#  'dessert panna cotta amaze',
#  'good food great atmosphere',
#  'damn good steak',
#  'total brunch fail',
#  'price reasonable flavor spot sauce home make slaw drench mayo',
#  'decor nice piano music soundtrack pleasant',
#  'steak amazingrge fillet relleno best seafood plate ever',
#  'good food good service',
#  'absolutely amaze',
#  'probably wont back honest',
#  'definitely back',
#  'sergeant pepper beef sandwich auju sauce excellent sandwich well',
#  'hawaiian breeze mango magic pineapple delight smoothy ive try far theyre good',
#  'go lunch service slow',
#  'much say place walk expect amaze quickly disappointed',
#  'mortify',
#  'needle say never back',
#  'anyways food definitely fill price pay expect',
#  'chip come drip grease mostly edible',
#  'wasnt really impressed strip steak',
#  'go since every meal awesome',
#  'server nice attentive serve staff',
#  'cashier friendly even brought food',
#  'work hospitality industry paradise valley refrain recommend cibo longer',
#  'atmosphere fun',
#  'would recommend others',
#  'service quick even go order like like',
#  'mean really get famous fish chip terrible',
#  'say mouth belly still quite pleased',
#  'thing',
#  'thumb',
#  'reading please dont go',
#  'love grill pizza remind legit italian pizza',
#  'pro large seat area nice bar area great simple drink menu best brick oven pizza homemade dough',
#  'really nice atmosphere',
#  'tonight elk filet specialand suck',
#  'one bite hooked',
#  'order old classic new dish go time sorely disappointed everything',
#  'cute quaint simple honest',
#  'chicken deliciously season perfect fry outside moist chicken inside',
#  'food great always compliment chef',
#  'special thanks dylan recommendation order yummy tummy',
#  'awesome selection beer',
#  'great food awesome service',
#  'one nice thing add gratuity bill since party large didnt expect tip',
#  'fly apple juice fly',
#  'han nan chicken also tasty',
#  'service thought good',
#  'food barely lukewarm must sit wait server bring u',
#  'ryans bar definitely one edinburgh establishment wont revisit',
#  'nice chinese restaurant ive',
#  'overall like food service',
#  'also serve indian naan bread hummus spicy pine nut sauce world',
#  'probably never come back wouldnt recommend',
#  'friend pasta also bad barely touch',
#  'try airport experience tasty food speedy friendly service',
#  'love decor chinese calligraphy wall paper',
#  'never anything complain',
#  'restaurant clean family restaurant feel',
#  'way fry',
#  'im sure long stood long enough begin feel awkwardly place',
#  'open sandwich impressed good way',
#  'back',
#  'warm feel service felt like guest special treat',
#  'extensive menu provide lot option breakfast',
#  'always order vegetarian menu dinner wide array option choose',
#  'watch price inflate portion get small management attitude grow rapidly',
#  'wonderful lil tapa ambience make feel warm fuzzy inside',
#  'get enjoy seafood salad fabulous vinegrette',
#  'wonton thin thick chewy almost melt mouth',
#  'level spicy perfect spice didnt overwhelm soup',
#  'sat right time server get go fantastic',
#  'main thing didnt enjoy crowd old crowd around mid',
#  'im side town definitely spot ill hit',
#  'wait minute get drink longer get arepas',
#  'great place eat',
#  'jalapeno bacon soooo good',
#  'service poor thats nice',
#  'food good service good price good',
#  'place clean food oh stale',
#  'chicken dish ok beef like shoe leather',
#  'service beyond bad',
#  'im happy',
#  'taste like dirt',
#  'one place phoenix would definately go back',
#  'block amaze',
#  'close house lowkey nonfancy affordable price good food',
#  'hot sour egg flower soup absolutely star',
#  'sashimi poor quality soggy tasteless',
#  'great time family dinner sunday night',
#  'food tasty say real traditional hunan style',
#  'bother slow service',
#  'flair bartender absolutely amaze',
#  'frozen margarita way sugary taste',
#  'good order twice',
#  'nutshell restaraunt smell like combination dirty fish market sewer',
#  'girlfriend veal bad',
#  'unfortunately good',
#  'pretty satifying experience',
#  'join club get awesome offer via email',
#  'perfect someone like beer ice cold case even colder',
#  'bland flavorless good way describe barely tepid meat',
#  'chain im fan beat place easily',
#  'nacho must',
#  'come back',
#  'dont many word say place everything pretty well',
#  'staff super nice quick even crazy crowd downtown jury lawyer court staff',
#  'great atmosphere friendly fast service',
#  'receive pita huge lot meat thumb',
#  'food arrives meh',
#  'pay hot dog fry look like come kid meal wienerschnitzel idea good meal',
#  'classic maine lobster roll fantastic',
#  'brother law work mall ate day guess sick night',
#  'good go review place twice hereas tribute place tribute event held last night',
#  'chip salsa really good salsa fresh',
#  'place great',
#  'mediocre food',
#  'get inside youll impressed place',
#  'im super pissd',
#  'service super friendly',
#  'sad little vegetable overcook',
#  'place nice surprise',
#  'goldencrispy delicious',
#  'high hope place since burger cooked charcoal grill unfortunately taste fell flat way flat',
#  'could eat bruschetta day devine',
#  'single employee come see ok even need water refill finally serve u food',
#  'lastly mozzarella stick best thing order',
#  'first time ever come amaze experience still tell people awesome duck',
#  'server negligent need make u feel unwelcome would suggest place',
#  'service terrible though',
#  'place overprice consistent boba really overprice',
#  'packed',
#  'love place',
#  'say dessert yummy',
#  'food terrible',
#  'seasonal fruit fresh white peach puree',
#  'kept get bad bad im officially do',
#  'place honestly blown',
#  'definitely would eat',
#  'waste money',
#  'love put food nice plastic container oppose cram little paper takeout box',
#  'crêpe delicate thin moist',
#  'awful service',
#  'wont ever go',
#  'food quality horrible',
#  'price think place would much rather go',
#  'service fair best',
#  'love sushi found kabuki overprice overhip underservices',
#  'favor stay away dish',
#  'poor service',
#  'one table thought food average worth wait',
#  'best service food ever maria server good friendly make day',
#  'excellent',
#  'paid bill tip felt server terrible job',
#  'lunch great experience',
#  'never bland food surprised consider article read focus much spice flavor',
#  'food way overprice portion fuck small',
#  'recently try caballeros back every week since',
#  'buck head really expect well food',
#  'food come good pace',
#  'ate twice last visit especially enjoy salmon salad',
#  'wont back',
#  'could believe dirty oyster',
#  'place deserves star',
#  'would recommend place',
#  'fact im go round star awesome',
#  'disbelief dish qualify bad version food ever taste',
#  'bad day low tolerance rude customer service people job nice polite wash dish otherwise',
#  'potato great biscuit',
#  'probably would go',
#  'flavorful perfect amount heat',
#  'price reasonable service great',
#  'wife hat meal coconut shrimp friend really enjoy meal either',
#  'fella get huevos rancheros didnt look appeal',
#  'go happy hour great list wine',
#  'may say buffet pricey think get pay place get quite lot',
#  'probably wont come back',
#  'bad foodservice ive',
#  'place pretty good nice little vibe restaurant',
#  'talk great customer service course back',
#  'hot dish hot cold dish close room tempo watch staff prepare food bare hand gloveseverything deep fry oil',
#  'love fry bean',
#  'always pleasure deal',
#  'plethora salad sandwich everything ive try get seal approval',
#  'place awesome want something light healthy summer',
#  'sushi strip place go',
#  'service great even manager come help table',
#  'feel din room college cooking course high class din service slow best',
#  'start review two star im edit give one',
#  'bad sushi ever eat besides costcos',
#  'excellent restaurant highlight great service unique menu beautiful set',
#  'boyfriend sat bar completely delightful experience',
#  'weird vibe owner',
#  'hardly meat',
#  'ive well bagel grocery store',
#  'go place gyro',
#  'love ownerchef one authentic japanese cool dude',
#  'burger arent good pizza use amaze doughy flavorless',
#  'found six inch long piece wire salsa',
#  'service terrible food mediocre',
#  'definately enjoy',
#  'order albondigas soup warm taste like tomato soup frozen meatball',
#  'three different occasion ask well do medium well three time get bloodiest piece meat plate',
#  'two bite refuse eat anymore',
#  'service extremely slow',
#  'minute wait get table',
#  'seriously killer hot chai latte',
#  'allergy warning menu waitress absolutely clue meal contain peanut',
#  'boyfriend try mediterranean chicken salad fell love',
#  'rotate beer tap also highlight place',
#  'pricing bit concern mellow mushroom',
#  'bad thai ever',
#  'stay vega must get breakfast least',
#  'want first say server great perfect service',
#  'pizza selection good',
#  'strawberry tea good',
#  'highly unprofessional rude loyal patron',
#  'overall great experience',
#  'spend money elsewhere',
#  'regular toast bread equally satisfy occasional pat butter mmmm',
#  'buffet bellagio far anticipate',
#  'drink weak people',
#  'order correct',
#  'also feel like chip bought make house',
#  'disappoint dinner go elsewhere dessert',
#  'chip sals amaze',
#  'wont return',
#  'new fav vega buffet spot',
#  'seriously cannot believe owner many unexperienced employee run around like chicken head cut',
#  'sad',
#  'felt insult disrespect could talk judge another human like',
#  'call steakhouse cant properly cook steak dont understand',
#  'im impressed concept food',
#  'thing wasnt crazy guacamole dont like puréed',
#  'really nothing postinos hope experience well',
#  'get food poison buffet',
#  'brought fresh batch fry think yay something warm',
#  'hilarious yummy christmas eve dinner remember big fail entire trip u',
#  'needle say wont go back anytime soon',
#  'place disgust',
#  'every time eat see care teamwork professional degree',
#  'ri style calamari joke',
#  'however much garlic fondue barely edible',
#  'could barely stomach meal didnt complain business lunch',
#  'bad lose heart finish',
#  'also take forever bring u check ask',
#  'arent one make scene restaurant dont get itdefinitely lose love one',
#  'disappoint experience',
#  'food par dennys say good',
#  'want wait mediocre food downright terrible service place',
#  'waaaaaayyyyyyyyyy rat say',
#  'wont go back',
#  'place fairly clean food simply wasnt worth',
#  'place lack style',
#  'sangria half glass wine full ridiculous',
#  'dont bother come',
#  'meat pretty dry slice brisket pull pork',
#  'building seem pretty neat bathroom pretty trippy wouldnt eat',
#  'equally awful',
#  'probably hurry go back',
#  'slow seat even reservation',
#  'good stretch imagination',
#  'cashew cream sauce bland vegetable undercooked',
#  'chipolte ranch dip sause tasteless seem thin water heat',
#  'bit sweet really spicy enough lack flavor',
#  'disappointed',
#  'place horrible way overprice',
#  'maybe vegetarian fare ive twice thought average best',
#  'wasnt busy know',
#  'table outside also dirty lot time worker always friendly helpful menu',
#  'ambiance feel like buffet set douchey indoor garden tea biscuit',
#  'con spotty service',
#  'fry hot neither burger',
#  'come back cold',
#  'food come disappointment ensue',
#  'real disappointment waiter',
#  'husband say rude even apologize bad food anything',
#  'reason eat would fill night binge drinking get carbs stomach',
#  'insult profound deuchebaggery go outside smoke break serve solidify',
#  'someone order two taco dont think may part customer service ask combo ala cart',
#  'quite disappointed although blame need place door',
#  'rave review couldnt wait eat herewhat disappointment',
#  'del taco pretty nasty avoid possible',
#  'hard make decent hamburger',
#  'dont like',
#  'hell go back',
#  'weve gotten much well service pizza place next door service receive restaurant',
#  'dont know big deal place wont back yaall',
#  'immediately say want talk manager want talk guy shot fireball behind bar',
#  'ambiance isnt much well',
#  'unfortunately set u disapppointment entree',
#  'food wasnt good',
#  'server suck wait correction server heimer suck',
#  'happen next prettyoff put',
#  'bad cause know family own really want like place',
#  'overprice get',
#  'vomit bathroom mid lunch',
#  'kept look time soon become minute yet still food',
#  'place eat circumstance would ever return top list',
#  'start tuna sashimi brownish color obviously wasnt fresh',
#  'food average',
#  'sure beat nacho movie would expect little bit come restaurant',
#  'ha long bay bit flop',
#  'problem charge sandwich big subway sub offer well amount vegetable',
#  'shrimp unwrapped live mile brushfire literally ice cold',
#  'lack flavor seem undercooked dry',
#  'really impressive place hasnt close',
#  'would avoid place stay mirage',
#  'refried bean come meal dry crusty food bland',
#  'spend money time place else',
#  'lady table next u found live green caterpillar salad',
#  'presentation food awful',
#  'cant tell disappointed',
#  'think food flavor texture lack',
#  'appetite instantly go',
#  'overall impressed would go back',
#  'whole experience underwhelming think well go ninja sushi next time',
#  'hadnt waste enough life pour salt wound draw time take bring check']

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence)))

words = list(sent_to_words(data))

# %%
id2word = corpora.Dictionary(words)                   

# Create Corpus
texts = words                                        

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]    

# View
print(corpus[:1][0][:30])
# Out:
# [(0, 1), (1, 1), (2, 1)]

# %%
num_topics = 10

# Build LDA model
lda_model = gensim.models.LdaMulticore(corpus=corpus,
                                       id2word=id2word,
                                       num_topics=num_topics)

# Print the Keyword in the 10 topics
pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.024*"food" + 0.014*"good" + 0.011*"well" + 0.010*"one" + 0.010*"get" + '
#   '0.010*"go" + 0.009*"sandwich" + 0.008*"salad" + 0.008*"say" + '
#   '0.008*"service"'),
#  (1,
#   '0.028*"place" + 0.020*"like" + 0.018*"service" + 0.015*"good" + 0.014*"bad" '
#   '+ 0.012*"go" + 0.012*"taste" + 0.011*"say" + 0.009*"also" + 0.009*"ever"'),
#  (2,
#   '0.022*"service" + 0.018*"great" + 0.017*"place" + 0.015*"food" + '
#   '0.010*"disappointed" + 0.010*"bad" + 0.010*"good" + 0.009*"like" + '
#   '0.009*"fry" + 0.008*"time"'),
#  (3,
#   '0.021*"back" + 0.019*"good" + 0.018*"go" + 0.017*"food" + 0.014*"great" + '
#   '0.010*"menu" + 0.010*"best" + 0.008*"place" + 0.008*"really" + '
#   '0.007*"nice"'),
#  (4,
#   '0.019*"come" + 0.019*"good" + 0.014*"back" + 0.014*"dont" + 0.014*"food" + '
#   '0.012*"service" + 0.010*"meal" + 0.010*"great" + 0.010*"amaze" + '
#   '0.009*"friendly"'),
#  (5,
#   '0.019*"service" + 0.015*"food" + 0.013*"good" + 0.012*"dish" + 0.012*"time" '
#   '+ 0.011*"order" + 0.009*"delicious" + 0.008*"eat" + 0.008*"get" + '
#   '0.008*"go"'),
#  (6,
#   '0.026*"place" + 0.015*"wait" + 0.015*"time" + 0.013*"get" + '
#   '0.012*"friendly" + 0.011*"staff" + 0.010*"love" + 0.009*"go" + 0.009*"nice" '
#   '+ 0.009*"food"'),
#  (7,
#   '0.029*"place" + 0.020*"great" + 0.020*"food" + 0.015*"come" + 0.013*"back" '
#   '+ 0.011*"eat" + 0.010*"good" + 0.009*"one" + 0.008*"didnt" + 0.008*"like"'),
#  (8,
#   '0.023*"good" + 0.021*"place" + 0.019*"food" + 0.015*"would" + 0.012*"great" '
#   '+ 0.009*"vega" + 0.009*"back" + 0.009*"go" + 0.009*"service" + 0.008*"eat"'),
#  (9,
#   '0.027*"food" + 0.020*"go" + 0.015*"service" + 0.011*"time" + 0.010*"great" '
#   '+ 0.010*"like" + 0.009*"ever" + 0.009*"price" + 0.009*"place" + '
#   '0.009*"never"')]

# %%
pyLDAvis.enable_notebook()

LDAvis = pyLDAvis.gensim_models.prepare(lda_model, corpus, id2word)

LDAvis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0      0.062410 -0.109075       1        1  13.323774
# 9      0.066221 -0.038125       2        1  11.386490
# 6      0.010301  0.048483       3        1  10.806979
# 8      0.091962  0.022290       4        1  10.484475
# 3     -0.053231 -0.033707       5        1  10.374018
# 7     -0.003239  0.066895       6        1  10.297764
# 5     -0.061323 -0.073055       7        1   8.718727
# 2     -0.042585  0.019605       8        1   8.553105
# 1      0.033310  0.084579       9        1   8.419502
# 4     -0.103826  0.012109      10        1   7.635166, topic_info=          Term       Freq      Total Category  logprob  loglift
# 1        place  86.000000  86.000000  Default  30.0000  30.0000
# 145       come  31.000000  31.000000  Default  29.0000  29.0000
# 319       wait  23.000000  23.000000  Default  28.0000  28.0000
# 32        like  39.000000  39.000000  Default  27.0000  27.0000
# 214       dont  22.000000  22.000000  Default  26.0000  26.0000
# ..         ...        ...        ...      ...      ...      ...
# 256  delicious   2.255401  18.440705  Topic10  -5.2446   0.4712
# 1        place   2.983310  86.781567  Topic10  -4.9649  -0.7980
# 364       best   2.255610  23.975495  Topic10  -5.2445   0.2088
# 0         love   2.255415  24.854898  Topic10  -5.2446   0.1727
# 44          go   2.255637  59.729772  Topic10  -5.2445  -0.7040
#
# [747 rows x 6 columns], token_table=      Topic      Freq           Term
# term
# 569       1  0.645721  accommodation
# 29        2  0.638101          ahead
# 1375      1  0.645723        airport
# 1629      7  0.655435            ala
# 1536      7  0.655434     albondigas
# ...     ...       ...            ...
# 647       9  0.671738          yukon
# 722       1  0.858698            yum
# 562       1  0.213781           zero
# 562       4  0.427563           zero
# 562       5  0.213781           zero
#
# [1445 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 10, 7, 9, 4, 8, 6, 3, 2, 5])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF



# Create a TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')
tfidf = tfidf_vectorizer.fit_transform(reviewsP['Review'])

# Define the number of topics
num_topics = 5

# Apply NMF
nmf = NMF(n_components=num_topics, random_state=42)
nmf.fit(tfidf)

# Display the topics and their top words
def display_topics(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print(f"Topic {topic_idx + 1}:")
        print([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]])

n_top_words = 5  # Number of top words per topic
print("Topics and their top words:")
display_topics(nmf, tfidf_vectorizer.get_feature_names_out(), n_top_words)
# Out:
# Topics and their top words:
# Topic 1:
# ['good', 'price', 'selection', 'really', 'pizza']
# Topic 2:
# ['place', 'love', 'recommend', 'like', 'eat']
# Topic 3:
# ['food', 'delicious', 'bad', 'terrible', 'amaze']
# Topic 4:
# ['service', 'friendly', 'slow', 'bad', 'fantastic']
# Topic 5:
# ['great', 'time', 'experience', 'eat', 'staff']
